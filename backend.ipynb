p":2374,"x":-0.05154023692011833,"y":-0.03695625811815262,"z":0.061084724962711334},{"sensor":"accelerometer","timestamp":2389,"x":0.13102799654006958,"y":0.2169160097837448,"z":0.9999119639396667},{"sensor":"gyroscope","timestamp":2408,"x":-0.01122431829571724,"y":-0.015576604753732681,"z":0.05131116881966591},{"sensor":"magnetometer","timestamp":2424,"x":-21.262500762939453,"y":-34.70625305175781,"z":-5.381250381469727},{"sensor":"accelerometer","timestamp":2440,"x":0.1290760040283203,"y":0.2169160097837448,"z":0.9957639575004578},{"sensor":"gyroscope","timestamp":2455,"x":0.03458922728896141,"y":0.017409147694706917,"z":0.04153761267662048},{"sensor":"accelerometer","timestamp":2474,"x":0.12346399575471878,"y":0.2227720022201538,"z":0.9833199977874756},{"sensor":"magnetometer","timestamp":2490,"x":-21,"y":-34.81875228881836,"z":-5.081250190734863},{"sensor":"gyroscope","timestamp":2507,"x":0.04558447748422623,"y":0.030847785994410515,"z":0.04337015375494957},{"sensor":"accelerometer","timestamp":2522,"x":0.1163880005478859,"y":0.2332640141248703,"z":0.965507984161377},{"sensor":"gyroscope","timestamp":2541,"x":0.010766183026134968,"y":0.02473931387066841,"z":0.06719319522380829},{"sensor":"magnetometer","timestamp":2556,"x":-21.150001525878906,"y":-34.98750305175781,"z":-5.100000381469727}]

# %%
import numpy as np
import pandas as pd
from scipy.signal import welch
from scipy.stats import skew, kurtosis

# Input: list of dictionaries containing sensor data with keys: sensor, timestamp, x, y, z
def extract_features(sensor_data):
    # Convert list of sensor data into a DataFrame
    df = pd.DataFrame(sensor_data)
    
    features = {}  # Store features as a dictionary initially
    
    def calculate_statistics(axis_data, axis_name):
        """Calculates basic statistics for each axis."""
        features[f'mean_{axis_name}'] = np.mean(axis_data)
        features[f'std_{axis_name}'] = np.std(axis_data)
        features[f'max_{axis_name}'] = np.max(axis_data)
        features[f'min_{axis_name}'] = np.min(axis_data)
        features[f'mad_{axis_name}'] = np.mean(np.abs(axis_data - np.mean(axis_data)))  # Mean Absolute Deviation
        features[f'skewness_{axis_name}'] = skew(axis_data)  # Skewness
        features[f'kurtosis_{axis_name}'] = kurtosis(axis_data)  # Kurtosis
        features[f'energy_{axis_name}'] = np.sum(axis_data**2) / len(axis_data)  # Signal energy


    def calculate_frequency_features(axis_data, axis_name):
        """Calculates frequency-domain features using Welch's method."""
        freqs, power = welch(axis_data, fs=50, nperseg=256)  # 50 Hz sampling rate
        features[f'freq_mean_{axis_name}'] = np.mean(power)
        features[f'freq_std_{axis_name}'] = np.std(power)
        features[f'freq_max_{axis_name}'] = np.max(power)
        features[f'freq_entropy_{axis_name}'] = -np.sum(power * np.log2(power + 1e-8))  # Spectral entropy
        
      

    # Split the data based on sensor type
    accel_data = df[df['sensor'] == 'accelerometer']
    gyro_data = df[df['sensor'] == 'gyroscope']
    mag_data = df[df['sensor'] == 'magnetometer']

    # Process accelerometer data (x, y, z)
    if not accel_data.empty:
        for axis in ['x', 'y', 'z']:
            calculate_statistics(accel_data[axis], f'accel_{axis}')
            calculate_frequency_features(accel_data[axis], f'accel_{axis}')

    # Process gyroscope data (x, y, z)
    if not gyro_data.empty:
        for axis in ['x', 'y', 'z']:
            calculate_statistics(gyro_data[axis], f'gyro_{axis}')
            calculate_frequency_features(gyro_data[axis], f'gyro_{axis}')

    # Process magnetometer data (x, y, z)
    if not mag_data.empty:
        for axis in ['x', 'y', 'z']:
            calculate_statistics(mag_data[axis], f'mag_{axis}')
            calculate_frequency_features(mag_data[axis], f'mag_{axis}')

    # Convert features dictionary to a DataFrame for easy reading
    features_df = pd.DataFrame([features])
    
    return features_df

features_df = extract_features(sensor_data)
print("Extracted Features DataFrame:")
features_df
# Out:
# Extracted Features DataFrame:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\signal\_spectral_py.py:600: UserWarning: nperseg = 256 is greater than input length  = 56, using nperseg = 56
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\signal\_spectral_py.py:600: UserWarning: nperseg = 256 is greater than input length  = 42, using nperseg = 42
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
#    mean_accel_x  std_accel_x  max_accel_x  min_accel_x  mad_accel_x  \
# 0      0.132884     0.019835     0.213256     0.104676     0.014067
#
#    skewness_accel_x  kurtosis_accel_x  energy_accel_x  freq_mean_accel_x  \
# 0          1.868686          4.765215        0.018052           0.000007
#
#    freq_std_accel_x  ...  max_mag_z  min_mag_z  mad_mag_z  skewness_mag_z  \
# ...

# %%
feature_mapping = {
    'mean_accel_x': 'tBodyAcc-mean()-X',
    'std_accel_x': 'tBodyAcc-std()-X',
    'max_accel_x': 'tBodyAcc-max()-X',
    'min_accel_x': 'tBodyAcc-min()-X',
    'mad_accel_x': 'tBodyAcc-mad()-X',
    'skewness_accel_x': 'fBodyAcc-skewness()-X',
    'kurtosis_accel_x': 'fBodyAcc-kurtosis()-X',
    'energy_accel_x': 'tBodyAcc-energy()-X',
    'freq_mean_accel_x': 'fBodyAcc-mean()-X',
    'freq_std_accel_x': 'fBodyAcc-std()-X',
    'freq_max_accel_x': 'fBodyAcc-max()-X',
    'freq_entropy_accel_x': 'fBodyAcc-entropy()-X',
    'mean_accel_y': 'tBodyAcc-mean()-Y',
    'std_accel_y': 'tBodyAcc-std()-Y',
    'max_accel_y': 'tBodyAcc-max()-Y',
    'min_accel_y': 'tBodyAcc-min()-Y',
    'mad_accel_y': 'tBodyAcc-mad()-Y',
    'skewness_accel_y': 'fBodyAcc-skewness()-Y',
    'kurtosis_accel_y': 'fBodyAcc-kurtosis()-Y',
    'energy_accel_y': 'tBodyAcc-energy()-Y',
    'freq_mean_accel_y': 'fBodyAcc-mean()-Y',
    'freq_std_accel_y': 'fBodyAcc-std()-Y',
    'freq_max_accel_y': 'fBodyAcc-max()-Y',
    'freq_entropy_accel_y': 'fBodyAcc-entropy()-Y',
    'mean_accel_z': 'tBodyAcc-mean()-Z',
    'std_accel_z': 'tBodyAcc-std()-Z',
    'max_accel_z': 'tBodyAcc-max()-Z',
    'min_accel_z': 'tBodyAcc-min()-Z',
    'mad_accel_z': 'tBodyAcc-mad()-Z',
    'skewness_accel_z': 'fBodyAcc-skewness()-Z',
    'kurtosis_accel_z': 'fBodyAcc-kurtosis()-Z',
    'energy_accel_z': 'tBodyAcc-energy()-Z',
    'freq_mean_accel_z': 'fBodyAcc-mean()-Z',
    'freq_std_accel_z': 'fBodyAcc-std()-Z',
    'freq_max_accel_z': 'fBodyAcc-max()-Z',
    'freq_entropy_accel_z': 'fBodyAcc-entropy()-Z'
}

# %%
columns_to_keep = list(feature_mapping.keys())

# Filter out only those 36 columns
features_df = features_df[columns_to_keep]

# %%
features_df
# Out:
#    mean_accel_x  std_accel_x  max_accel_x  min_accel_x  mad_accel_x  \
# 0      0.132884     0.019835     0.213256     0.104676     0.014067
#
#    skewness_accel_x  kurtosis_accel_x  energy_accel_x  freq_mean_accel_x  \
# 0          1.868686          4.765215        0.018052           0.000007
#
#    freq_std_accel_x  ...  max_accel_z  min_accel_z  mad_accel_z  \
# 0          0.000019  ...     1.012112     0.897432     0.017952
#
#    skewness_accel_z  kurtosis_accel_z  energy_accel_z  freq_mean_accel_z  \
# 0         -0.921923          1.212241        0.953224           0.000012
#
#    freq_std_accel_z  freq_max_accel_z  freq_entropy_accel_z
# 0          0.000024           0.00009              0.005023
#
# [1 rows x 36 columns]

# %%
features_df.columns
# Out:
# Index(['mean_accel_x', 'std_accel_x', 'max_accel_x', 'min_accel_x',
#        'mad_accel_x', 'skewness_accel_x', 'kurtosis_accel_x', 'energy_accel_x',
#        'freq_mean_accel_x', 'freq_std_accel_x', 'freq_max_accel_x',
#        'freq_entropy_accel_x', 'mean_accel_y', 'std_accel_y', 'max_accel_y',
#        'min_accel_y', 'mad_accel_y', 'skewness_accel_y', 'kurtosis_accel_y',
#        'energy_accel_y', 'freq_mean_accel_y', 'freq_std_accel_y',
#        'freq_max_accel_y', 'freq_entropy_accel_y', 'mean_accel_z',
#        'std_accel_z', 'max_accel_z', 'min_accel_z', 'mad_accel_z',
#        'skewness_accel_z', 'kurtosis_accel_z', 'energy_accel_z',
#        'freq_mean_accel_z', 'freq_std_accel_z', 'freq_max_accel_z',
#        'freq_entropy_accel_z'],
#       dtype='object')

# %%
features_df.isnull().sum()
# Out:
# mean_accel_x            0
# std_accel_x             0
# max_accel_x             0
# min_accel_x             0
# mad_accel_x             0
# skewness_accel_x        0
# kurtosis_accel_x        0
# energy_accel_x          0
# freq_mean_accel_x       0
# freq_std_accel_x        0
# freq_max_accel_x        0
# freq_entropy_accel_x    0
# mean_accel_y            0
# std_accel_y             0
# max_accel_y             0
# min_accel_y             0
# mad_accel_y             0
# skewness_accel_y        0
# kurtosis_accel_y        0
# energy_accel_y          0
# freq_mean_accel_y       0
# freq_std_accel_y        0
# freq_max_accel_y        0
# freq_entropy_accel_y    0
# mean_accel_z            0
# std_accel_z             0
# max_accel_z             0
# min_accel_z             0
# mad_accel_z             0
# skewness_accel_z        0
# kurtosis_accel_z        0
# energy_accel_z          0
# freq_mean_accel_z       0
# freq_std_accel_z        0
# freq_max_accel_z        0
# ...

# %% [markdown]
# # Prediction

# %%
import pandas as pd
import joblib

# Load the saved model
rf_model = joblib.load('random_forest_model.joblib')

# Predict activities using the trained model
predictions = rf_model.predict(features_df)

# Add predictions to the DataFrame for reference
features_df['predicted_activity'] = predictions

# Output the predictions
print(features_df[['predicted_activity']])
# Out:
#    predicted_activity
# 0                   2
# C:\Users\DELL\AppData\Local\Temp\ipykernel_740\284753134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df['predicted_activity'] = predictions
